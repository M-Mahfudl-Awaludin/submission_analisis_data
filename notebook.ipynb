# %% [markdown]
# # Proyek Analisis Data: [Air Quality Dataset]
# - **Nama:** M Mahfudl Awaludin
# - **Email:** mahfudawaludin.009@gmail.com
# - **ID Bangkit:** m704b4ky2323

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - pertanyaan 1 : Bagaimana kualitas udara berdasarkan tahun, bulan, hari, & jam?
# - Pertanyaan 2 : Bagaimana Pengaruh SO2, NO2, CO dan O3 terhadap kualitas udara?
# - pertanyaan 3 : Daerah mana sajakah yang memiliki kualitas udara yang terbaik & terendah dari rentang 2013 - 2017?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Menyiapkan DataSet
airql1_df = pd.read_csv("./data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
airql2_df = pd.read_csv('./data/PRSA_Data_Changping_20130301-20170228.csv')
airql3_df = pd.read_csv('./data/PRSA_Data_Dingling_20130301-20170228.csv')
airql4_df = pd.read_csv('./data/PRSA_Data_Dongsi_20130301-20170228.csv')
airql5_df = pd.read_csv('./data/PRSA_Data_Guanyuan_20130301-20170228.csv')
airql6_df = pd.read_csv('./data/PRSA_Data_Gucheng_20130301-20170228.csv')
airql7_df = pd.read_csv('./data/PRSA_Data_Huairou_20130301-20170228.csv')
airql8_df = pd.read_csv('./data/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
airql9_df = pd.read_csv('./data/PRSA_Data_Shunyi_20130301-20170228.csv')
airql10_df = pd.read_csv('./data/PRSA_Data_Tiantan_20130301-20170228.csv')
airql11_df = pd.read_csv('./data/PRSA_Data_Wanliu_20130301-20170228.csv')
airql12_df = pd.read_csv('./data/PRSA_Data_Wanshouxigong_20130301-20170228.csv')

# Menggabungkan semua data menjadi satu dataframe
df_airql = pd.concat([airql1_df, airql2_df, airql3_df, airql4_df, airql5_df, airql6_df, airql7_df, airql8_df, airql9_df, airql10_df, airql11_df, airql12_df], axis=0)
df_airql = df_airql.reset_index() #menambahkan column index baru
df_airql
# Out:
#         index     No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO  \
# 0           0      1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0
# 1           1      2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0
# 2           2      3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0
# 3           3      4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0
# 4           4      5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0
# ...       ...    ...   ...    ...  ...   ...    ...   ...   ...   ...    ...
# 420763  35059  35060  2017      2   28    19   11.0  32.0   3.0  24.0  400.0
# 420764  35060  35061  2017      2   28    20   13.0  32.0   3.0  41.0  500.0
# 420765  35061  35062  2017      2   28    21   14.0  28.0   4.0  38.0  500.0
# 420766  35062  35063  2017      2   28    22   12.0  23.0   4.0  30.0  400.0
# 420767  35063  35064  2017      2   28    23   13.0  19.0   4.0  38.0  600.0
#
# ...

# %%
# Mennghapus column yang tidak diperlukan
df_airql = df_airql.drop(['No'], axis=1)
df_airql.head(10)
# Out:
#    index  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0      0  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1      1  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2      2  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3      3  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4      4  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# 5      5  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2
# 6      6  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6
# 7      7  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6
# 8      8  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1
# 9      9  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# ...

# %%
# Menambahkan column Baru "Date" dan "Time"
from datetime import datetime

df_airql['datetime'] = df_airql.apply(lambda row: datetime(row['year'], row['month'], row['day'], row['hour']),  axis=1) 

#mendindahkan column datetime ke paling kiri
df_datetime = df_airql['datetime']
df_airql.drop('datetime', axis=1, inplace=True)
df_airql.insert(0, 'datetime', df_datetime)

df_airql.head(10) #menampilkan 5 baris pertama
# Out:
#              datetime  index  year  month  day  hour  PM2.5  PM10   SO2   NO2  \
# 0 2013-03-01 00:00:00      0  2013      3    1     0    4.0   4.0   4.0   7.0
# 1 2013-03-01 01:00:00      1  2013      3    1     1    8.0   8.0   4.0   7.0
# 2 2013-03-01 02:00:00      2  2013      3    1     2    7.0   7.0   5.0  10.0
# 3 2013-03-01 03:00:00      3  2013      3    1     3    6.0   6.0  11.0  11.0
# 4 2013-03-01 04:00:00      4  2013      3    1     4    3.0   3.0  12.0  12.0
# 5 2013-03-01 05:00:00      5  2013      3    1     5    5.0   5.0  18.0  18.0
# 6 2013-03-01 06:00:00      6  2013      3    1     6    3.0   3.0  18.0  32.0
# 7 2013-03-01 07:00:00      7  2013      3    1     7    3.0   6.0  19.0  41.0
# 8 2013-03-01 08:00:00      8  2013      3    1     8    3.0   6.0  16.0  43.0
# 9 2013-03-01 09:00:00      9  2013      3    1     9    3.0   8.0  12.0  28.0
#
#       CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
# merubah nama column
df_airql['month'] = df_airql['month'].map({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'})

# %%
# merubah data column hour
def hour_to_string(hour):
   return f'{hour:02}:00'

list_hour = [hour_to_string(hour) for hour in df_airql['hour']]
df_airql['hour'] = list_hour

# %%
# mengganti data column day
import calendar

def day_to_string(number):
    day_number = int(number - 1) % 7 # 1 Jan 2013 adalah hari Selasa
    return calendar.day_name[day_number]

df_airql['day'] = df_airql['day'].apply(day_to_string)

# %%
# menambah nama setiap column dengan prefix 'column_'
df_airql = df_airql.add_prefix('column_')

# %%
# mengganti nama column 'aqi_datetime' menjadi 'datetime'
df_airql.rename(columns={'aqi_datetime': 'datetime'}, inplace=True)

# %%
# merubah column "yaer", "month", "day", "hour" menjadi category
column = ["column_year", "column_month", "column_day", "column_hour"]
df_airql[column] = df_airql[column].astype('category')

# %% [markdown]
# ### Assessing Data

# %%
#memeriksa tipe data
print('type(df_airql):', type(df_airql))
df_airql.info()
# Out:
# type(df_airql): <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   column_datetime  420768 non-null  datetime64[ns]
#  1   column_index     420768 non-null  int64
#  2   column_year      420768 non-null  category
#  3   column_month     420768 non-null  category
#  4   column_day       420768 non-null  category
#  5   column_hour      420768 non-null  category
#  6   column_PM2.5     412029 non-null  float64
#  7   column_PM10      414319 non-null  float64
#  8   column_SO2       411747 non-null  float64
#  9   column_NO2       408652 non-null  float64
#  10  column_CO        400067 non-null  float64
#  11  column_O3        407491 non-null  float64
#  12  column_TEMP      420370 non-null  float64
#  13  column_PRES      420375 non-null  float64
# ...

# %%
# memeriksa missing value
print('| jumlah missing value: |')
print(df_airql.isnull().sum())
# Out:
# | jumlah missing value: |
# column_datetime        0
# column_index           0
# column_year            0
# column_month           0
# column_day             0
# column_hour            0
# column_PM2.5        8739
# column_PM10         6449
# column_SO2          9021
# column_NO2         12116
# column_CO          20701
# column_O3          13277
# column_TEMP          398
# column_PRES          393
# column_DEWP          403
# column_RAIN          390
# column_wd           1822
# column_WSPM          318
# column_station         0
# dtype: int64

# %%
#memeriksa data duplikat
print(f'jumlah data duplicate: {df_airql.duplicated().sum()}')
# Out:
# jumlah data duplicate: 0

# %%
df_airql.describe()
# Out:
#                      column_datetime   column_index   column_PM2.5  \
# count                         420768  420768.000000  412029.000000
# mean   2015-03-01 11:30:00.000001024   17531.500000      79.793428
# min              2013-03-01 00:00:00       0.000000       2.000000
# 25%              2014-03-01 05:45:00    8765.750000      20.000000
# 50%              2015-03-01 11:30:00   17531.500000      55.000000
# 75%              2016-02-29 17:15:00   26297.250000     111.000000
# max              2017-02-28 23:00:00   35063.000000     999.000000
# std                              NaN   10122.116943      80.822391
#
#          column_PM10     column_SO2     column_NO2      column_CO  \
# count  414319.000000  411747.000000  408652.000000  400067.000000
# mean      104.602618      15.830835      50.638586    1230.766454
# min         2.000000       0.285600       1.026500     100.000000
# 25%        36.000000       3.000000      23.000000     500.000000
# ...

# %% [markdown]
# **Insight:**
# Hasil Identifikasi
# - jumblah data duplikasi : 0
# - data missing value : column [column_datetime,column_PM2.5, column_PM10, column_SO2, column_NO2, column_CO, column_O3, column_TEMP, column_PRES, column_DEWP, column_RAIN, column_wd, column_WSPM]

# %% [markdown]
# ### Cleaning Data

# %%
#Menangani missing value
df_airql.isna().sum()
# Out:
# column_datetime        0
# column_index           0
# column_year            0
# column_month           0
# column_day             0
# column_hour            0
# column_PM2.5        8739
# column_PM10         6449
# column_SO2          9021
# column_NO2         12116
# column_CO          20701
# column_O3          13277
# column_TEMP          398
# column_PRES          393
# column_DEWP          403
# column_RAIN          390
# column_wd           1822
# column_WSPM          318
# column_station         0
# dtype: int64

# %% [markdown]
# **Insight:**
# Terdapat missing value yang berbeda-beda.
# - missing value di bawah 5000 dihapus,
# - missing value antara 5000-15000 diganti nilainya dengan nilai mean/mode
# - missing value di atas 15000 diganti dengan median agar tidak terganggu dengan outliernya

# %%
#Menghapus missing value dibawah 5000
df_airql.dropna(subset=['column_TEMP', 'column_PRES', 'column_DEWP', 'column_RAIN', 'column_wd', 'column_WSPM'], axis=0, inplace=True)

# %%
#Mengganti missing value 5000-15000 dengan nilai mean/mode
name_column = ['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_O3']

for column in name_column:
    mean = df_airql[column].mean()
    df_airql[column].fillna(mean, axis=0, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3887222705.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_airql[column].fillna(mean, axis=0, inplace=True)

# %%
#Mengganti missing value 15000 dengan nilai median
median_value = df_airql['column_CO'].median()
df_airql['column_CO'].fillna(median_value, axis=0, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3867855205.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_airql['column_CO'].fillna(median_value, axis=0, inplace=True)

# %%
#Memeriksa missing value
print(df_airql.isna().sum())
# Out:
# column_datetime    0
# column_index       0
# column_year        0
# column_month       0
# column_day         0
# column_hour        0
# column_PM2.5       0
# column_PM10        0
# column_SO2         0
# column_NO2         0
# column_CO          0
# column_O3          0
# column_TEMP        0
# column_PRES        0
# column_DEWP        0
# column_RAIN        0
# column_wd          0
# column_WSPM        0
# column_station     0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Missing Value Tidak Ada

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# menampilkan parameter statistik
df_airql.describe(include='all')
# Out:
#                       column_datetime   column_index  column_year  \
# count                          418858  418858.000000     418858.0
# unique                            NaN            NaN          5.0
# top                               NaN            NaN       2014.0
# freq                              NaN            NaN     105105.0
# mean    2015-02-27 12:05:34.638468864   17484.092955          NaN
# min               2013-03-01 00:00:00       0.000000          NaN
# 25%               2014-02-27 17:00:00    8729.000000          NaN
# 50%               2015-02-27 01:00:00   17473.000000          NaN
# 75%               2016-02-27 03:00:00   26235.000000          NaN
# max               2017-02-28 23:00:00   35063.000000          NaN
# std                               NaN   10110.297282          NaN
#
#        column_month column_day column_hour   column_PM2.5    column_PM10  \
# count        418858     418858      418858  418858.000000  418858.000000
# ...

# %% [markdown]
# ### Explore
# clustering kualitas udara berdasarkan dengan beberapa faktor (pm2.5, pm10, so2, no2, co, o3) dan faktor lainnya (temp, pres, dewp, rain, wd, wspm)

# %% [markdown]
# **Insight:** Clustering kualitas udara berdasarkan dengan beberapa faktor (pm2.5, pm10, so2, no2, co, o3) dan faktor lainnya (temp, pres, dewp, rain, wd, wspm)

# %%
# batasan standar deviasi setiap faktor untuk menentukan kualitas udara
def det_air_quality(PM25, PM10, SO2, NO2, CO, O3):
    standar = {
        'PM25': [(0, 12), (12, 35), (35, float('inf'))],
        'PM10': [(0, 50), (50, 100), (100, float('inf'))],
        'SO2': [(0, 20), (20, 100), (100, float('inf'))],
        'NO2': [(0, 40), (40, 100), (100, float('inf'))],
        'CO': [(0, 1000), (1000, 5000), (5000, float('inf'))],
        'O3': [(0, 100), (100, 180), (180, float('inf'))]
    }

# fungsi untuk menentukan kualitas udara
    def det_quality(parameter, value):
        for  quality, law in enumerate(standar[parameter], start=1):
            if isinstance(law, tuple):
                if law[0] <= value < law[1]:
                    return quality
                else:
                    if value == law[1]:
                        return quality
                return 3

    PM25_quality = det_quality('PM25', float(PM25))
    PM10_quality = det_quality('PM10', float(PM10))
    SO2_quality = det_quality('SO2', float(SO2))
    NO2_quality = det_quality('NO2', float(NO2))
    CO_quality = det_quality('CO', float(CO))
    O3_quality = det_quality('O3', float(O3))

    

# menghitung rata - rata kualitas udara
    average_quality = (PM25_quality + PM10_quality + SO2_quality + NO2_quality + CO_quality + O3_quality) / 6

    if average_quality < 2:
        return 'Bersih'
    elif average_quality < 2.5:
        return 'Sedang'
    else:
        return 'Buruk'

df_airql['quality_air'] = df_airql.apply(lambda row: det_air_quality(row['column_PM2.5'], row['column_PM10'], row['column_SO2'], row['column_NO2'], row['column_CO'], row['column_O3']), axis=1)

df_airql['quality_air'] = df_airql['quality_air'].astype('category')

# %%
#mengecek kode dengan 20 sampel
df_airql.sample(20)
# Out:
#            column_datetime  column_index column_year column_month column_day  \
# 44487  2014-03-28 15:00:00          9423        2014          Mar     Sunday
# 39678  2013-09-09 06:00:00          4614        2013          Sep    Tuesday
# 50549  2014-12-06 05:00:00         15485        2014          Dec   Saturday
# 269656 2015-12-04 16:00:00         24208        2015          Dec   Thursday
# 102039 2016-10-20 15:00:00         31911        2016          Oct   Saturday
# 148699 2014-02-15 19:00:00          8443        2014          Feb     Monday
# 141367 2013-04-16 07:00:00          1111        2013          Apr    Tuesday
# 102120 2016-10-24 00:00:00         31992        2016          Oct  Wednesday
# 336728 2015-07-30 08:00:00         21152        2015          Jul    Tuesday
# 329799 2014-10-14 15:00:00         14223        2014          Oct     Sunday
# 85074  2014-11-13 18:00:00         14946        2014          Nov   Saturday
# ...

# %%
#melihat hasil output kualitas udara 
df_airql['quality_air'].value_counts()
# Out:
# quality_air
# Sedang    175561
# Bersih    164376
# Buruk      78921
# Name: count, dtype: int64

# %%
# membuat kolom jika udara bersih 1 sedang 0 dan buruk -1 untuk memudahkan visualisasi
df_airql['index_aqi'] = df_airql['quality_air']
df_airql['index_aqi'] = df_airql['index_aqi'].map({'Bersih': 1, 'Sedang': 0, 'Buruk': -1})
df_airql['index_aqi'] = df_airql['index_aqi'].astype('int')

# %%
# menampilkan jumlah data dan tipe data
df_airql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418858 entries, 0 to 420767
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   column_datetime  418858 non-null  datetime64[ns]
#  1   column_index     418858 non-null  int64
#  2   column_year      418858 non-null  category
#  3   column_month     418858 non-null  category
#  4   column_day       418858 non-null  category
#  5   column_hour      418858 non-null  category
#  6   column_PM2.5     418858 non-null  float64
#  7   column_PM10      418858 non-null  float64
#  8   column_SO2       418858 non-null  float64
#  9   column_NO2       418858 non-null  float64
#  10  column_CO        418858 non-null  float64
#  11  column_O3        418858 non-null  float64
#  12  column_TEMP      418858 non-null  float64
#  13  column_PRES      418858 non-null  float64
#  14  column_DEWP      418858 non-null  float64
#  15  column_RAIN      418858 non-null  float64
# ...

# %%
# cek data parameter statistik kolom_PM2.5, kolom_PM10, kolom_SO2, kolom_NO2, kolom_CO, kolom_O3 berdasarkan kualitas udara
df_airql.groupby(by ='quality_air')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'], 
                                                                                                                               'column_PM10': ['max', 'min', 'mean'],
                                                                                                                               'column_SO2': ['max', 'min', 'mean'],
                                                                                                                               'column_NO2': ['max', 'min', 'mean'],
                                                                                                                               'column_CO': ['max', 'min', 'mean'],
                                                                                                                               'column_O3': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2620032897.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='quality_air')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'],
#             column_PM2.5                  column_PM10                   \
#                      max  min        mean         max  min        mean
# quality_air
# Bersih             500.0  2.0   24.216790       999.0  2.0   40.339784
# Buruk              999.0  3.0  157.869622       999.0  5.0  190.250060
# Sedang             804.0  3.0   96.525553       987.0  2.0  126.120365
#
#             column_SO2                    column_NO2                     \
# ...

# %% [markdown]
# **Insight:**
#
# Berdasarkan hasil tersebut di dapatkan informasi bahwa, baris baik pada kolom kualitas_udara memiliki nilai mean yang relatif lebih rendah jika di bandingkan baris lain. Jika di kelompokkan berdasarkan nilai mean dari yang terkecil
#
# * baik
# * sedang
# * buruk

# %%
# cek data parameter statistik kolom_PM2.5, kolom_PM10, kolom_SO2, kolom_NO2, kolom_CO, kolom_O3 berdasarkan tempat station
df_airql.groupby(by ='column_station')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'], 
                                                                                                                               'column_PM10': ['max', 'min', 'mean'],
                                                                                                                               'column_SO2': ['max', 'min', 'mean'],
                                                                                                                               'column_NO2': ['max', 'min', 'mean'],
                                                                                                                               'column_CO': ['max', 'min', 'mean'],
                                                                                                                               'column_O3': ['max', 'min', 'mean']})
# Out:
#                column_PM2.5                 column_PM10                   \
#                         max  min       mean         max  min        mean
# column_station
# Aotizhongxin          898.0  3.0  82.675086       984.0  2.0  109.946421
# Changping             882.0  2.0  71.179889       999.0  2.0   94.720732
# Dingling              881.0  3.0  66.188317       905.0  2.0   84.055196
# Dongsi                737.0  3.0  86.017997       955.0  2.0  110.196997
# Guanyuan              680.0  2.0  82.854068       999.0  2.0  108.935650
# Gucheng               770.0  2.0  83.686124       994.0  2.0  118.646175
# Huairou               762.0  2.0  69.762001       993.0  2.0   91.722954
# Nongzhanguan          844.0  2.0  84.720816       995.0  2.0  108.911015
# Shunyi                941.0  2.0  78.980924       999.0  2.0   98.302053
# Tiantan               821.0  3.0  82.103133       988.0  2.0  106.333994
# Wanliu                957.0  2.0  83.330616       951.0  2.0  110.424038
# ...

# %% [markdown]
# **Insight:** Berdasarkan hasil tersebut di dapatkan hasil bahwa
#
# *
# *
# Daerah Dingling, Huairou, dan Changping memeiliki nilai mean terend
# * Daerah Nongzhanguan, Gucheng, Wanliu dan dongsi memiliki nilai mean tertinggiggi

# %%
# cek data parameter statistik kolom_PM2.5, kolom_PM10, kolom_SO2, kolom_NO2, kolom_CO, kolom_O3 berdasarkan tahun
df_airql.groupby(by ='column_year')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'], 
                                                                                                                               'column_PM10': ['max', 'min', 'mean'],
                                                                                                                               'column_SO2': ['max', 'min', 'mean'],
                                                                                                                               'column_NO2': ['max', 'min', 'mean'],
                                                                                                                               'column_CO': ['max', 'min', 'mean'],
                                                                                                                               'column_O3': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\57581555.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_year')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'],
#             column_PM2.5                 column_PM10                   \
#                      max  min       mean         max  min        mean
# column_year
# 2013               844.0  2.0  80.010274       999.0  2.0  102.823659
# 2014               809.0  3.0  85.419711       999.0  3.0  115.870830
# 2015               762.0  3.0  79.540518       999.0  3.0  103.556222
# 2016               999.0  3.0  71.916931       995.0  3.0   94.605875
# 2017               835.0  2.0  92.153426       994.0  3.0  110.752470
#
# ...

# %% [markdown]
# **Insight:**
#
#
# * PM2.5 (Partikel Matter 2.5 Mikrometer): rata-rata paling sedikit pada tahun 2016 dan paling banyak 2017
#
# * PM10 (Partikel Matter 10 Mikrometer): rata-rata paling sedikit pada tahun 2016 dan paling banyak 2014
#
# * SO2 (Dioksida Belerang): rata-rata paling sedikit pada tahun 2016 dan paling banyak 2014
#
# * NO2 (Dioksida Nitrogen): rata-rata paling sediki pada tahun 2016 dan paling banyak 2014
#
# * CO (Karbon Monoksida): rata-rata paling sedikit pada tahun 2016 dan paling banyak 2017
#
# * O3 (Ozon): rata-rata paling sedikit pada tahun 2017 dan paling banyak 2015i

# %%
# cek data parameter statistik kolom_PM2.5, kolom_PM10, kolom_SO2, kolom_NO2, kolom_CO, kolom_O3 berdasarkan bulan
df_airql.groupby(by ='column_month')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'], 
                                                                                                                               'column_PM10': ['max', 'min', 'mean'],
                                                                                                                               'column_SO2': ['max', 'min', 'mean'],
                                                                                                                               'column_NO2': ['max', 'min', 'mean'],
                                                                                                                               'column_CO': ['max', 'min', 'mean'],
                                                                                                                               'column_O3': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\1690080191.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_month')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'],
#              column_PM2.5                  column_PM10                   \
#                       max  min        mean         max  min        mean
# column_month
# Apr                 533.0  2.0   72.889229       999.0  2.0  116.719498
# Aug                 500.0  3.0   53.854657       748.0  2.0   71.834993
# Dec                 741.0  3.0  103.656280       948.0  2.0  124.731482
# Feb                 999.0  3.0   87.302109       992.0  3.0  102.547699
# ...

# %% [markdown]
# **Insight:**
#
#
# * Bulan Agustus, Juli, & Juni memeiliki nilai mean terendah
# * Bulan januari, Desember, & Maret memiliki nilai mean tertinggi

# %%
# cek data parameter statistik kolom_PM2.5, kolom_PM10, kolom_SO2, kolom_NO2, kolom_CO, kolom_O3 berdasarkan hari
df_airql.groupby(by ='column_day')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'], 
                                                                                                                               'column_PM10': ['max', 'min', 'mean'],
                                                                                                                               'column_SO2': ['max', 'min', 'mean'],
                                                                                                                               'column_NO2': ['max', 'min', 'mean'],
                                                                                                                               'column_CO': ['max', 'min', 'mean'],
                                                                                                                               'column_O3': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2791114234.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_day')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'],
#            column_PM2.5                 column_PM10                   \
#                     max  min       mean         max  min        mean
# column_day
# Friday            844.0  3.0  75.608879       991.0  2.0  100.043696
# Monday            999.0  3.0  83.874959       999.0  2.0  111.123577
# Saturday          646.0  2.0  75.518608       995.0  2.0   97.836651
# Sunday            835.0  2.0  82.905926       994.0  2.0  106.499951
# Thursday          705.0  2.0  80.715441       857.0  2.0  103.564897
# ...

# %% [markdown]
# **Insight:**
#
# * Hari Selasa, Senin & Rabu memeiliki nilai mean terendah
# * hari Minggu, Kamis & Sabtu memiliki nilai mean tertinggi

# %%
# cek data parameter statistik kolom_PM2.5, kolom_PM10, kolom_SO2, kolom_NO2, kolom_CO, kolom_O3 berdasarkan jam
df_airql.groupby(by ='column_hour')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'], 
                                                                                                                               'column_PM10': ['max', 'min', 'mean'],
                                                                                                                               'column_SO2': ['max', 'min', 'mean'],
                                                                                                                               'column_NO2': ['max', 'min', 'mean'],
                                                                                                                               'column_CO': ['max', 'min', 'mean'],
                                                                                                                               'column_O3': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\1658873748.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_hour')[['column_PM2.5', 'column_PM10', 'column_SO2', 'column_NO2', 'column_CO', 'column_O3']].agg({'column_PM2.5': ['max', 'min', 'mean'],
#             column_PM2.5                 column_PM10                   \
#                      max  min       mean         max  min        mean
# column_hour
# 00:00              809.0  3.0  87.392862       986.0  2.0  114.691758
# 01:00              881.0  3.0  86.462239       991.0  2.0  111.045779
# 02:00              999.0  3.0  84.398700       995.0  2.0  106.521868
# 03:00              857.0  3.0  81.845857       992.0  2.0  102.117386
# 04:00              801.0  2.0  79.285087       973.0  2.0   97.798374
# ...

# %% [markdown]
# **Insight:**
#
#
# * Jam 06:00, 05:00 & 04:00 memeiliki nilai mean terendah
# * Jam 21:00, 20:00 & 22:00 memiliki nilai mean tertinggi

# %%
# cek kualitas berdasarkan tempat station
df_airql.groupby(by ='column_station').agg({'quality_air': 'value_counts'})
# Out:
#                             quality_air
# column_station quality_air
# Aotizhongxin   Sedang             15544
#                Bersih             12192
#                Buruk               7241
# Changping      Bersih             15815
#                Sedang             13367
#                Buruk               5731
# Dingling       Bersih             20189
#                Sedang             10914
#                Buruk               3810
# Dongsi         Sedang             14318
#                Bersih             12517
#                Buruk               8145
# Guanyuan       Sedang             15305
#                Bersih             12075
#                Buruk               7597
# Gucheng        Sedang             16511
#                Bersih             11214
#                Buruk               7173
# Huairou        Bersih             17677
#                Sedang             12881
#                Buruk               4196
# Nongzhanguan   Sedang             14555
# ...

# %% [markdown]
# **Insight:**
#
# * kualitas udara baik paling banyak berada di daerah Dingling, dan paling sedikit berada di daerah Gucheng
# * Kualitas udara sedang paling banyak berada di daerah Gucheng, dan paling sedikit berada di daerah Dingling
# * Kualitas udara buruk paling banyak berada di daerah Nongzhanguan, dan paling sedikit berada di daerah Dingling

# %%
# cek kualitas berdasarkan tahun
df_airql.groupby(by ='column_year').agg({'quality_air': 'value_counts'})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2519217004.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_year').agg({'quality_air': 'value_counts'})
#                          quality_air
# column_year quality_air
# 2013        Sedang             39244
#             Bersih             31272
#             Buruk              17578
# 2014        Sedang             45475
#             Bersih             34384
#             Buruk              25246
# 2015        Bersih             43857
#             Sedang             42277
#             Buruk              18389
# 2016        Bersih             47196
#             Sedang             43673
#             Buruk              13762
# 2017        Bersih              7667
#             Sedang              4892
# ...

# %%
# cek kualitas berdasarkan bulan
df_airql.groupby(by ='column_month').agg({'quality_air': 'value_counts'})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\1151286795.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_month').agg({'quality_air': 'value_counts'})
#                           quality_air
# column_month quality_air
# Apr          Sedang             16638
#              Bersih             12121
#              Buruk               5751
# Aug          Bersih             17456
#              Sedang             17193
#              Buruk                993
# Dec          Bersih             12863
#              Buruk              12018
#              Sedang             10699
# Feb          Bersih             15080
#              Buruk              10337
#              Sedang              6857
# Jan          Buruk              14568
# ...

# %% [markdown]
# **Insight:**
#
# * Kualitas udara baik paling banyak di bulan Agustus, dan paling sedikit di bulan januari
# * Kualitas udara sedang paling banyak di bulan Maret dan paling sedikit di bulan Agustus
# * Kualitas udara buruk paling banyak di bulan Desember, dan paling sedikit di bulan Agustus

# %%
# cek kualitas berdasarkan hari
df_airql.groupby(by ='column_day').agg({'quality_air': 'value_counts'})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3541043606.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_day').agg({'quality_air': 'value_counts'})
#                         quality_air
# column_day quality_air
# Friday     Sedang             23529
#            Bersih             22582
#            Buruk               8966
# Monday     Sedang             28070
#            Bersih             25792
#            Buruk              14113
# Saturday   Sedang             23019
#            Bersih             22048
#            Buruk               9972
# Sunday     Sedang             23808
#            Bersih             20329
#            Buruk              10885
# Thursday   Sedang             23594
#            Bersih             22112
# ...

# %% [markdown]
# **Insight:**
#
# * Kualitas udara baik paling banyak di hari Kamis, dan paling sedikit di hari Minggu
# * Kualitas udara sedang paling banyak di hari Senin dan paling sedikit di hari Jumat
# * Kualitas udara buruk paling banyak di hari Senin, dan paling sedikit di hari Juma

# %%
# cek kualitas berdasarkan jam
df_airql.groupby(by ='column_hour').agg({'quality_air': 'value_counts'})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2787070396.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_hour').agg({'quality_air': 'value_counts'})
#                          quality_air
# column_hour quality_air
# 00:00       Sedang              8027
#             Bersih              6202
#             Buruk               3207
# 01:00       Sedang              7783
#             Bersih              6656
# ...                              ...
# 22:00       Bersih              5337
#             Buruk               3608
# 23:00       Sedang              8218
#             Bersih              5791
#             Buruk               3405
#
# [72 rows x 1 columns]

# %% [markdown]
# #### TEMPERATURE, PRESSURE, DEW POINT dan WIND SPEED

# %%
# cek temp, pres, dewp, rain, wd, wspm berdasarkan kualitas udara
df_airql.groupby(by ='quality_air').agg({'column_TEMP': ['max', 'min', 'mean'],
                                       'column_PRES': ['max', 'min', 'mean'],
                                       'column_DEWP': ['max', 'min', 'mean'],
                                       'column_RAIN': ['max', 'min', 'mean'],
                                       'column_WSPM': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3875041290.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='quality_air').agg({'column_TEMP': ['max', 'min', 'mean'],
#             column_TEMP                  column_PRES                      \
#                     max   min       mean         max    min         mean
# quality_air
# Bersih             41.4 -19.9  13.467697      1042.8  982.4  1011.477361
# Buruk              39.2 -15.2   7.634480      1037.0  985.4  1014.242206
# Sedang             41.6 -15.7  16.316828      1038.5  982.4  1008.456395
#
#             column_DEWP                 column_RAIN                 \
#                     max   min      mean         max  min      mean
# quality_air
# ...

# %%
# cek temp, pres, dewp, rain, wd, wspm berdasarkan tempat station
df_airql.groupby(by ='column_station').agg({'column_TEMP': ['max', 'min', 'mean'],
                                          'column_PRES': ['max', 'min', 'mean'],
                                          'column_DEWP': ['max', 'min', 'mean'],
                                          'column_RAIN': ['max', 'min', 'mean'],
                                          'column_WSPM': ['max', 'min', 'mean']})
# Out:
#                column_TEMP                  column_PRES                      \
#                        max   min       mean         max    min         mean
# column_station
# Aotizhongxin          40.5 -16.8  13.600094      1042.0  985.9  1011.835904
# Changping             41.4 -16.6  13.705645      1036.5  982.4  1007.745621
# Dingling              41.4 -16.6  13.705645      1036.5  982.4  1007.745621
# Dongsi                41.1 -16.8  13.687112      1042.0  987.1  1012.537433
# Guanyuan              40.5 -16.8  13.600094      1042.0  985.9  1011.835904
# Gucheng               41.6 -15.6  13.875923      1038.1  984.0  1008.830782
# Huairou               40.3 -19.9  12.477479      1036.5  982.8  1007.576458
# Nongzhanguan          41.1 -16.8  13.687112      1042.0  987.1  1012.537433
# Shunyi                40.6 -16.8  13.467495      1042.8  988.0  1013.012335
# Tiantan               41.1 -16.8  13.687112      1042.0  987.1  1012.537433
# ...

# %%
# cek temp, pres, dewp, rain, wd, wspm berdasarkan tahun
df_airql.groupby(by ='column_year').agg({'column_TEMP': ['max', 'min', 'mean'],
                                       'column_PRES': ['max', 'min', 'mean'],
                                       'column_DEWP': ['max', 'min', 'mean'],
                                       'column_RAIN': ['max', 'min', 'mean'],
                                       'column_WSPM': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3396349325.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_year').agg({'column_TEMP': ['max', 'min', 'mean'],
#             column_TEMP                    column_PRES                      \
#                     max     min       mean         max    min         mean
# column_year
# 2013               38.0 -11.600  15.692061      1033.8  982.9  1007.733006
# 2014               41.6 -14.500  13.915448      1037.0  983.6  1010.642132
# 2015               39.3 -13.800  13.447486      1039.4  982.4  1011.114525
# 2016               38.2 -19.900  13.599983      1042.8  984.8  1011.215562
# 2017               16.2 -13.425   0.446815      1037.6  997.1  1021.825704
#
# ...

# %%
# cek temp, pres, dewp, rain, wd, wspm berdasarkan bulan
df_airql.groupby(by ='column_month').agg({'column_TEMP': ['max', 'min', 'mean'],
                                        'column_PRES': ['max', 'min', 'mean'],
                                        'column_DEWP': ['max', 'min', 'mean'],
                                        'column_RAIN': ['max', 'min', 'mean'],
                                        'column_WSPM': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\1541134015.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_month').agg({'column_TEMP': ['max', 'min', 'mean'],
#              column_TEMP                  column_PRES                       \
#                      max   min       mean         max     min         mean
# column_month
# Apr                 32.3  -1.6  15.331941      1031.2   985.4  1008.309280
# Aug                 37.7  12.9  26.648993      1015.2   985.2  1001.231104
# Dec                 15.4 -11.9  -0.228004      1037.1  1000.0  1021.518392
# Feb                 16.2 -14.5   1.132914      1038.0   997.1  1020.323274
# Jan                 14.0 -19.9  -1.785663      1042.8  1001.0  1022.099339
# ...

# %%
# cek temp, pres, dewp, rain, wd, wspm berdasarkan hari
df_airql.groupby(by ='column_day').agg({'column_TEMP': ['max', 'min', 'mean'],
                                      'column_PRES': ['max', 'min', 'mean'],
                                      'column_DEWP': ['max', 'min', 'mean'],
                                      'column_RAIN': ['max', 'min', 'mean'],
                                      'column_WSPM': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3404646331.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_day').agg({'column_TEMP': ['max', 'min', 'mean'],
#            column_TEMP                       column_PRES                      \
#                    max        min       mean         max    min         mean
# column_day
# Friday            39.0 -16.400000  13.714111      1038.0  982.4  1010.623347
# Monday            41.6 -15.900000  13.510918      1042.8  984.8  1010.808027
# Saturday          39.3 -13.000000  13.443880      1037.1  983.2  1011.177623
# Sunday            37.9 -12.366667  13.547536      1036.0  986.5  1011.017223
# Thursday          38.2 -14.600000  13.658819      1036.0  982.9  1010.381343
# ...

# %%
# cek temp, pres, dewp, rain, wd, wspm berdasarkan jam
df_airql.groupby(by ='column_hour').agg({'column_TEMP': ['max', 'min', 'mean'],
                                       'column_PRES': ['max', 'min', 'mean'],
                                       'column_DEWP': ['max', 'min', 'mean'],
                                       'column_RAIN': ['max', 'min', 'mean'],
                                       'column_WSPM': ['max', 'min', 'mean']})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\4189097191.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_airql.groupby(by ='column_hour').agg({'column_TEMP': ['max', 'min', 'mean'],
#             column_TEMP                  column_PRES                      \
#                     max   min       mean         max    min         mean
# column_hour
# 00:00              32.8 -18.9  11.302703      1041.5  985.3  1011.148192
# 01:00              32.6 -19.7  10.857039      1040.9  985.3  1011.065542
# 02:00              31.0 -19.5  10.373513      1040.4  985.2  1011.057582
# 03:00              30.7 -19.9  10.001262      1040.1  985.0  1010.961113
# 04:00              30.3 -18.5   9.684358      1039.6  984.8  1010.964318
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana kualitas udara berdasarkan tahun, bulan, hari, & jam?

# %%
cat_var = ['column_year', 'column_month', 'column_day', 'column_hour']

# %%
# Membuat subplot grid
fig, ax= plt.subplots(nrows= 2, ncols= int(len(cat_var)/2), figsize= (25,9))

# Membuat main title
plt.suptitle('Countplots trends categorical independent variables'.upper(), fontsize= 20, fontweight= 20, y= 0.99)

# Looping untuk mengisi subplot grid dengan plots
k= 0
for i in range(2):
    for j in range(int(len(cat_var)/2)):
        sns.barplot(y= df_airql.groupby(by= cat_var[k]).index_aqi.sum(),
                    x= df_airql.groupby(by= cat_var[k]).mean(numeric_only=True).index, ax= ax[i,j], palette= 'winter')


        ax[i,j].set_title(f'{cat_var[k].upper()}', fontsize= 15)
        ax[i,j].set_ylabel('')
        ax[i,j].set_xlabel('')
        k+=1

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2788065216.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.barplot(y= df_airql.groupby(by= cat_var[k]).index_aqi.sum(),
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2788065216.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   x= df_airql.groupby(by= cat_var[k]).mean(numeric_only=True).index, ax= ax[i,j], palette= 'winter')
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\2788065216.py:11: FutureWarning:
#
# ...

# %% [markdown]
# ### Pertanyaan 2: Bagaimana Pengaruh SO2, NO2, CO dan O3 terhadap kualitas udara?

# %%
# pengaruh pm2.5 pm10 so2 no2 co o3 terhadap kualitas udara
df_airql['column_SO2'] = df_airql['column_SO2'].astype('float')
df_airql['column_NO2'] = df_airql['column_NO2'].astype('float')
df_airql['column_CO'] = df_airql['column_CO'].astype('float')
df_airql['column_O3'] = df_airql['column_O3'].astype('float')

# %%
# membuat dataframe baru berisi nilai mean berdasarkan kualitas udara
df_mean_quality = df_airql.groupby(by='quality_air').agg({
    'column_SO2': 'mean',
    'column_NO2': 'mean',
    'column_CO': 'mean',
    'column_O3': 'mean',
})
df_mean_quality
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\1259637423.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_mean_quality = df_airql.groupby(by='quality_air').agg({
#              column_SO2  column_NO2    column_CO  column_O3
# quality_air
# Bersih         5.674283   25.367375   515.465883  60.477098
# Buruk         47.079046   85.509142  2461.735609  44.132865
# Sedang        11.325742   58.519686  1303.979756  60.738608

# %%
df_mean_quality = df_mean_quality.T
df_mean_quality
# Out:
# quality_air      Bersih        Buruk       Sedang
# column_SO2     5.674283    47.079046    11.325742
# column_NO2    25.367375    85.509142    58.519686
# column_CO    515.465883  2461.735609  1303.979756
# column_O3     60.477098    44.132865    60.738608

# %%
species = ("SO2", "NO2", "CO", "O3")

# mengatur posisi lebar dan jarak
x = np.arange(len(species))
width = 0.25
multiplier = 1

fig, ax = plt.subplots(figsize=(10, 8))  # Membuat subplot grid dengan ukuran plot yang disesuaikan

# looping untuk mengisi subplot grid dengan plots
for attribute, measurement in df_mean_quality.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=10, rotation=30)
    multiplier += 1

# Menambah text, title,& label
ax.set_ylabel('Mean Value')
ax.set_title('Pengaruh SO2, NO2, CO, O3 terhadap Kualitas Udara')
ax.set_xticks(x + width * (multiplier - 1) / 2)
ax.set_xticklabels(species)  
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(-2, 3000)
bbox_props = dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white', lw=2)
plt.text(0.03, -0.1, 'Keterangan \nSO2 = Sulfur Dioxide, \nNO2 = Nitrogen Dioxide, \nCO = Carbon Monoxide, \nO3 = Ozone',
         fontsize=12, color='black', bbox=bbox_props, transform=plt.gcf().transFigure)


plt.show()

# %% [markdown]
# ### Pertanyaan 3: Daerah mana yang memiliki kualitas udara terendah dan terbaik dari rentang tahun 2013 sampai 2017?

# %%
# daerah yang memiliki kualitas udara buruk dan bersih berdasarkan tahun rentang 2013 - 2017
station_df = df_airql.groupby(by =['column_station']).index_aqi.sum().sort_values(ascending=False).reset_index()

# %%
# Membuat subplots grid untuk menampilkan visualisasi
fig, ax = plt.subplots(figsize=(24, 6), nrows=1, ncols=2)

# Membuat warna untuk visualisasi
colors1 = ["#72ff33" , "#D3D3D9", "#D3D3D9", "#D3D3D9", "#D3D3D9"]
colors2 = ["#ff3333" , "#D3D3D9", "#D3D3D9", "#D3D3D9", "#D3D3D9"]

# Membuat barplot ax[0]
sns.barplot(x='index_aqi', y='column_station', data=station_df.head(5), palette=colors1, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title('Best Air Quality', loc='center', fontsize=15, fontweight='bold')
ax[0].tick_params(axis='x', labelsize=12)

# Membuat barplot ax[1]
sns.barplot(x='index_aqi', y='column_station', data=station_df.sort_values(by='index_aqi', ascending=True).head(5), palette=colors2, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position('right')
ax[1].yaxis.tick_right()
ax[1].set_title('Worst Air Quality by Station', loc='center', fontsize=15, fontweight='bold')
ax[1].tick_params(axis='x', labelsize=12)

plt.suptitle('Best and Worst Air Quality by Station', fontsize=30, fontweight='bold')
plt.tight_layout() 
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3400002175.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='index_aqi', y='column_station', data=station_df.head(5), palette=colors1, ax=ax[0])
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\3400002175.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='index_aqi', y='column_station', data=station_df.sort_values(by='index_aqi', ascending=True).head(5), palette=colors2, ax=ax[1])

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * Conclusion Pertanyaan 1  : Kualitas udara terbaik di tahun 2016, dan terendah di tahun 2017. Berdasarkan bulan kualitas udara terbaik di bulan Agustus, dan terendah Januari. Berdasarkan hari kualitas udara terbaik di hari selasa dan jumat, dan terendah di hari Minggu. Berdasarkan waktu jam kualitas udara terbaik di jam 06:00, dan terendah di jam 21:00.
# * Conclusion Pertanyaan 2  : Pengaruh SO2, NO2, CO dan O3 terhadap kualitas udara sangat berpengaruh terhadap kualitas udara disini menandakan bahwa semakin tinggi carbon monoxide (CO) maka kualitas udara akan semakin buruk.
# * Conclution pertanyaan 3  : Daerah yang memiliki kualitas udara terendah adalah wanliu, nozhuang, dan diikuti gucheng, dan yang memiliki kualitas udara terbaik adalah dingling, huairou, dan changping.

# %%
#Ekspor dataset 
df_airql.to_csv("df_Air_Quality.csv", index=False )
